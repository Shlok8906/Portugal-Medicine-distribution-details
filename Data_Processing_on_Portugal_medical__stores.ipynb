# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('/content/Portugal Sales.xlsx',sheet_name="Portugal Sub-National Sales", header=2)
df.sample()
# Out:
#       Country Name      Brick Code                           Brick Name  \
# 72515      PORTUGAL  UG2.WPT.FR010  SILVES 1(S BART MESSINES,S MARCO »)
#
#       Month Date Panel ( Venta Directa /Sell-In) DESC  \
# 72515 2024-02-01                               RETAIL
#
#                               Brand   \
# 72515  DABIGATRAN ETEXILATE BIOGARAN
#
#                                              Brand Pack   \
# 72515  DABIGATRAN ETEXILATE BIOGARAN CAPSULE 110MG/1C...
#
#        Product Sales Pack Units (Unfactored)  -  IQVIA Subnational Sales  \
# 72515                                                 15
#
#        Product Sales Euros (Unfactored) -  IQVIA Subnational Sales
# 72515                                             528.13

# %%
df.shape
# Out:
# (205155, 9)

# %%
df.columns
# Out:
# Index(['Country Name ', 'Brick Code', 'Brick Name', 'Month Date',
#        'Panel ( Venta Directa /Sell-In) DESC', 'Brand ', 'Brand Pack ',
#        'Product Sales Pack Units (Unfactored)  -  IQVIA Subnational Sales',
#        'Product Sales Euros (Unfactored) -  IQVIA Subnational Sales'],
#       dtype='object')

# %%
df['Product Sales Pack Units (Unfactored)  -  IQVIA Subnational Sales'].describe()
# Out:
# count    205155.000000
# mean         22.493680
# std          57.603253
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%          18.000000
# max        2025.000000
# Name: Product Sales Pack Units (Unfactored)  -  IQVIA Subnational Sales, dtype: float64

# %%
df['Product Sales Euros (Unfactored) -  IQVIA Subnational Sales'].describe()
# Out:
# count    205155.000000
# mean       1131.586757
# std        3291.618115
# min           0.000000
# 25%           0.000000
# 50%          20.430000
# 75%         671.840000
# max      132783.300000
# Name: Product Sales Euros (Unfactored) -  IQVIA Subnational Sales, dtype: float64

# %%
df.isnull().sum()
# Out:
# Country Name                                                         0
# Brick Code                                                           0
# Brick Name                                                           0
# Month Date                                                           0
# Panel ( Venta Directa /Sell-In) DESC                                 0
# Brand                                                                0
# Brand Pack                                                           0
# Product Sales Pack Units (Unfactored)  -  IQVIA Subnational Sales    0
# Product Sales Euros (Unfactored) -  IQVIA Subnational Sales          0
# dtype: int64

# %%
df['Brand Pack '].value_counts().to_csv('Medicine.csv')

# %%
df['Brick Name'].value_counts().to_csv('Medical_Stores.csv')

# %%
df['Panel ( Venta Directa /Sell-In) DESC'].value_counts()
# Out:
# Panel ( Venta Directa /Sell-In) DESC
# RETAIL    205155
# Name: count, dtype: int64

# %%
import pandas as pd

# Clean column names
df.columns = df.columns.str.strip()

# Group by Brand and Brand Pack, and count how many times each combo appears
combo_counts = df.groupby(['Brand', 'Brand Pack']).size().reset_index(name='Count')
combo_counts.to_csv('combo_counts.csv', index=False)

# %%
df['Month Date'].value_counts()
# Out:
# Month Date
# 2023-09-01    13677
# 2023-10-01    13677
# 2023-11-01    13677
# 2023-12-01    13677
# 2024-01-01    13677
# 2024-02-01    13677
# 2024-03-01    13677
# 2024-04-01    13677
# 2024-05-01    13677
# 2024-06-01    13677
# 2024-07-01    13677
# 2024-08-01    13677
# 2024-09-01    13677
# 2024-10-01    13677
# 2024-11-01    13677
# Name: count, dtype: int64

# %%
sns.barplot(x='Product Sales Euros (Unfactored) -  IQVIA Subnational Sales',y='Month Date',data=df)
# Out:
# <Axes: xlabel='Product Sales Euros (Unfactored) -  IQVIA Subnational Sales', ylabel='Month Date'>

# %%
combo_counts=pd.read_csv('/content/combo_counts.csv')

sns.barplot(x='Count',y='Brand',data=combo_counts)
# Out:
# <Axes: xlabel='Count', ylabel='Brand'>

# %%
sns.lineplot(x="Month Date", y="Product Sales Euros (Unfactored) -  IQVIA Subnational Sales", data=df)
# Out:
# <Axes: xlabel='Month Date', ylabel='Product Sales Euros (Unfactored) -  IQVIA Subnational Sales'>
